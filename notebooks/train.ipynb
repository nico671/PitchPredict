# %%
import logging
import os
import pickle
import sys
import time
from pathlib import Path
from statistics import mean

import numpy as np
import polars as pl
import yaml
from sklearn.calibration import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
from pathlib import Path

import numpy as np
import tensorflow as tf
import yaml

from dvclive import Live
from dvclive.keras import DVCLiveCallback

params = Path("../params.yaml")
with open(params, "r") as file:
    params = yaml.safe_load(file)
DROPOUT = params["train"]["dropout"]
PATIENCE = params["train"]["patience"]
KERN_REG = params["train"]["kernel_regularizer"]
BATCH_NORMALIZATION = params["train"]["batch_normalization"]
BATCH_SIZE = params["train"]["batch_size"]
EPOCHS = params["train"]["epochs"]
LSTM_UNITS = params["train"]["lstm_units"]


def compile_and_fit(model, X_train, y_train, X_val, y_val, pitcher_name):
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=1e-4,  # - learning_rate: controls how much to change the model in response to the estimated error each time the model weights are updated.
        clipnorm=1.0,  # - clipnorm: clips gradients by norm; helps prevent exploding gradients.
        weight_decay=1e-4,  # - weight_decay: adds a penalty to the loss function to prevent overfitting.
    )
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["sparse_categorical_accuracy"],
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_sparse_categorical_accuracy",
            patience=PATIENCE,
            restore_best_weights=True,
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.2,
            patience=PATIENCE,
            min_lr=1e-6,
        ),
        DVCLiveCallback(live=Live(f"dvclive/{pitcher_name}_logs")),
    ]

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
    )

    return history


def create_model(input_shape, num_classes):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(shape=input_shape))
    model.add(
        tf.keras.layers.LSTM(
            LSTM_UNITS,
            return_sequences=True,
            dropout=DROPOUT,
            kernel_regularizer=tf.keras.regularizers.l2(KERN_REG),
        )
    )
    if BATCH_NORMALIZATION:
        model.add(tf.keras.layers.BatchNormalization())
    model.add(
        tf.keras.layers.LSTM(
            LSTM_UNITS,
            return_sequences=True,
            dropout=DROPOUT,
            kernel_regularizer=tf.keras.regularizers.l2(KERN_REG),
        )
    )
    if BATCH_NORMALIZATION:
        model.add(tf.keras.layers.BatchNormalization())
    model.add(
        tf.keras.layers.LSTM(
            LSTM_UNITS,
            dropout=DROPOUT,
            kernel_regularizer=tf.keras.regularizers.l2(KERN_REG),
        )
    )
    if BATCH_NORMALIZATION:
        model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dense(num_classes, activation="softmax"))
    return model


def calculate_class_weights(y):
    proportions = np.bincount(y) / len(y)
    for i, proportion in enumerate(proportions):
        if proportion == 0:
            proportions[i] = 1e-6
    inverseN = 1 / len(proportions)
    weights = [inverseN / proportion for proportion in proportions]
    return {i: w for i, w in enumerate(weights)}

# %%
df = pl.read_parquet(Path("../" + params["train"]["input_data_path"]))

# %%
logger = logging.getLogger("choo choo")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setFormatter(
    logging.Formatter("%(asctime)s - %(name)s - %(levelname)s - %(message)s")
)
logger.addHandler(handler)

# %%
def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X[i : (i + time_steps)]
        Xs.append(v)
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
def create_training_data(pitcher_df, features):
    # sort the data by game_date, game_pk, at_bat_number, pitch_number
    pitcher_df = pitcher_df.sort(
        [
            "game_date",
            "game_pk",
            "at_bat_number",
            "pitch_number",
        ],
        descending=False,
    )

    # select features and target variable for initial split of X and y
    X = pitcher_df.select(pl.col(features)).to_numpy()
    y = pitcher_df.select(pl.col("next_pitch")).to_numpy().ravel()

    # encode target variable
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    y = y_encoded

    # declare time steps
    params_path = Path("../params.yaml")
    with open(params_path, "r") as file:
        params = yaml.safe_load(file)

    time_steps = params["train"]["time_steps"]

    X_seq, y_seq = create_sequences(X, y, time_steps)
    # convert to correct datatypes for model
    X_seq = X_seq.astype("float32")
    y_seq = y_seq.astype("int32")  # Ensure labels are integers

    # split into train, test, val
    train_split = params["train"]["train_split"]
    train_size = int(len(X_seq) * train_split)
    val_size = int(len(X_seq) * (1 - train_split) / 2)
    X_train, X_val, X_test = np.split(X_seq, [train_size, train_size + val_size])
    y_train, y_val, y_test = np.split(y_seq, [train_size, train_size + val_size])

    # scale features, no reason for minmax tbh, just read a stackoverflow that recommended it
    scaler = MinMaxScaler()
    n_samples, n_timesteps, n_features = X_train.shape
    X_train_reshaped = X_train.reshape(-1, n_features)
    X_train_scaled = scaler.fit_transform(X_train_reshaped)
    X_train_scaled = X_train_scaled.reshape(n_samples, n_timesteps, n_features)
    X_val_scaled = scaler.transform(X_val.reshape(-1, n_features)).reshape(X_val.shape)
    X_test_scaled = scaler.transform(X_test.reshape(-1, n_features)).reshape(
        X_test.shape
    )

    # logger.info("Unique labels in y_train:", list(np.unique(y_train)))
    # logger.info("Unique labels in y_val:", list(np.unique(y_val)))
    # logger.info("Unique labels in y_test:", list(np.unique(y_test)))

    return (
        X_train_scaled,
        y_train,
        X_val_scaled,
        y_val,
        X_test_scaled,
        y_test,
        label_encoder,
    )

# %%
def training_loop(df, params):
    pitcher_data = {}
    count = 0
    features = []
    features_path = Path("../" + params["train"]["features_path"])
    with open(features_path, "r") as f:
        for item in f.readlines():
            features.append(item.strip())
    start_time = time.time()
    for pitcher_df in df.group_by("pitcher"):
        pitcher_code = pitcher_df[0]
        pitcher_df = pitcher_df[1]

        pitcher_name = pitcher_df.select(pl.first("player_name")).item()
        num_pitches = len(pitcher_df)
        logger.info(
            f"Training model for pitcher: {pitcher_name} - {num_pitches} pitches"
        )
        X_train, y_train, X_val, y_val, X_test, y_test, label_encoder = (
            create_training_data(pitcher_df, features)
        )

        lstm_model = create_model(X_train.shape[1:], len(label_encoder.classes_))
        history = compile_and_fit(
            lstm_model,
            X_train,
            y_train,
            X_val,
            y_val,
            pitcher_name,
        )
        most_common_pitch_rate = pitcher_df.select(
            pl.col("pitch_type").value_counts().sort(descending=False).head(1)
        ).item()["count"] / len(pitcher_df)

        print(f"Most common pitch rate for {pitcher_name}: {most_common_pitch_rate}")
        test_loss, test_accuracy = lstm_model.evaluate(X_test, y_test)
        pitcher_data[pitcher_code] = {
            "model": lstm_model,
            "history": history,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "total_pitches": len(y_test) + len(y_train) + len(y_val),
            "unique_classes": len(np.unique(y_train)),
            "player_name": pitcher_name,
            "X_test": X_test,
            "y_test": y_test,
            "label_encoder": label_encoder,
            "most_common_pitch_rate": most_common_pitch_rate,
            "performance_gain": (test_accuracy - most_common_pitch_rate) * 100,
        }
        logger.info(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}")
        logger.info(
            f" Accuracy Gained over guessing most common pitch for {pitcher_name}: {pitcher_data[pitcher_code]["performance_gain"]:.2f}%",
        )
        logger.info(
            f"Average Test Accuracy: {mean([pitcher_data[pitcher]['test_accuracy'] for pitcher in pitcher_data])*100:.2f}%"
        )

        logger.info(
            f"Average Performance Gained over guessing most common pitch: {mean([pitcher_data[pitcher]['performance_gain'] for pitcher in pitcher_data]):.2f}%"
        )

        count += 1
        logger.info(
            f'{count} of {len(df.select(pl.col("pitcher")).unique())}, {(count/len(df.select(pl.col("pitcher")).unique())) * 100:.2f}% done!'
        )
    end_time = time.time()
    logger.info(f"Training took {end_time - start_time} seconds")
    return pitcher_data

# %%
pitcher_data = training_loop(df, params)
# Out:
# 2024-12-17 12:35:08,168 - choo choo - INFO - Training model for pitcher: Flexen, Chris - 2797 pitches
# 2024-12-17 12:35:08,168 - choo choo - INFO - Training model for pitcher: Flexen, Chris - 2797 pitches
# Epoch 1/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2:08 2s/step - loss: 5.6107 - sparse_categorical_accuracy: 0.06 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5781 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6052 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6181 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6189 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6164 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6127 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6077 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6028 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5974 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5927 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5886 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5847 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5812 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5781 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5754 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 5.5738 - sparse_categorical_accuracy: 0.1013 - val_loss: 4.9687 - val_sparse_categorical_accuracy: 0.1277 - learning_rate: 1.0000e-04
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.0809 - sparse_categorical_accuracy: 0.06 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2552 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3019 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3083 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3084 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3100 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3093 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3111 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3120 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3117 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3114 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3112 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3106 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3098 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3089 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3065 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3044 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3023 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.2996 - sparse_categorical_accuracy: 0.1200 - val_loss: 4.8874 - val_sparse_categorical_accuracy: 0.1253 - learning_rate: 1.0000e-04
# Epoch 3/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.9875 - sparse_categorical_accuracy: 0.21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0668 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1200 - sparse_categorical_accuracy: 0.14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1495 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1557 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.1604 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1633 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1638 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1653 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1684 - sparse_categorical_accuracy: 0. 35/6136/61 ━━━━━━━━━━━ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ━━━━━━━━━ 0s0s  19ms/step - loss: 5.1706 - sparse_categorical_accuracy: 0.1336 19ms/step - loss: 5.1707 - sparse_categorical_accuracy: 0.13360s 19ms/step - loss: 5.1706 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1707 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1700 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1689 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1676 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1658 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1635 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1613 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1602 - sparse_categorical_accuracy: 0.1332 - val_loss: 4.8085 - val_sparse_categorical_accuracy: 0.1205 - learning_rate: 1.0000e-04
# Epoch 4/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.7773 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.7967 - sparse_categorical_accuracy: 0.15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8345 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8588 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8758 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8906 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8948 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9045 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9153 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9245 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9318 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9368 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9409 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9446 - sparse_categorical_accuracy: 0.15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9463 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9468 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9471 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9471 - sparse_categorical_accuracy: 0.16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9468 - sparse_categorical_accuracy: 0.1610 - val_loss: 4.7560 - val_sparse_categorical_accuracy: 0.1157 - learning_rate: 1.0000e-04
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.8811 - sparse_categorical_accuracy: 0.06 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9405 - sparse_categorical_accuracy: 0.08 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9340 - sparse_categorical_accuracy: 0.08 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9322 - sparse_categorical_accuracy: 0.09 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9306 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9302 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9247 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9203 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9174 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9150 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9112 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9070 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9036 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8996 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8956 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8920 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8889 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8858 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.8843 - sparse_categorical_accuracy: 0.1334 - val_loss: 4.6628 - val_sparse_categorical_accuracy: 0.1566 - learning_rate: 1.0000e-04
# Epoch 6/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.7414 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8179 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8169 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8120 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8070 - sparse_categorical_accuracy: 0.13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8045 - sparse_categorical_accuracy: 0.14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8015 - sparse_categorical_accuracy: 0.14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.7997 - sparse_categorical_accuracy: 0.14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.7968 - sparse_categorical_accuracy: 0.14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.
 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2829 - sparse_categorical_accuracy: 0.80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2786 - sparse_categorical_accuracy: 0.80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2749 - sparse_categorical_accuracy: 0.80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2731 - sparse_categorical_accuracy: 0.8103 - val_loss: 2.0475 - val_sparse_categorical_accuracy: 0.9133 - learning_rate: 1.0000e-04
# Epoch 23/200
# 61/61/step - loss: 2.1070 - sparse_categorical_accuracy: 0.8559_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2048 - sparse_categorical_accuracy: 0.83 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1620 - sparse_categorical_accuracy: 0.84 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1261 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1149 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1081 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1073 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1070 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 32/61 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1070 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1070 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1068 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1070 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1068 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1062 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1055 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1042 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1027 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1014 - sparse_categorical_accuracy: 0.85 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0998 - sparse_categorical_accuracy: 0.8536 - val_loss: 1.9174 - val_sparse_categorical_accuracy: 0.9133 - learning_rate: 1.0000e-04
# Epoch 24/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7846 - sparse_categorical_accuracy: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8710 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8920 - sparse_categorical_accuracy: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.8972 - sparse_categorical_accuracy: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.8997 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9076 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9178 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.9250 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9308 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9346 - sparse_categorical_accuracy: 0.86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.9368 - sparse_categorical_accuracy: 0.86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9387 - sparse_categorical_accuracy: 0.86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9387 - sparse_categorical_accuracy: 0.86 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9386 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9385 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9383 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9382 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9378 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9373 - sparse_categorical_accuracy: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9370 - sparse_categorical_accuracy: 0.8722 - val_loss: 1.8126 - val_sparse_categorical_accuracy: 0.9446 - learning_rate: 1.0000e-04
# Epoch 25/200
# 61/61━━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8416 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8223 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8235 - sparse_categorical_accuracy: 0.91 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8443 - sparse_categorical_accuracy: 0.91 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8468 - sparse_categorical_accuracy: 0.91 ━━━━20/61  0s━━━━━━ 17ms/step - loss: 1.8504 - sparse_categorical_accuracy: 0.9121/61  0s━━━━━━ 17ms/step - loss: 1.8513 - sparse_categorical_accuracy: 0.91 22/61 0s━━━━━━━ 18ms/step - loss: 1.8523 - sparse_categorical_accuracy: 0.9127━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8528 - sparse_categorical_accuracy: 0.91 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8529 - sparse_categorical_accuracy: 0.91 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8522 - sparse_categorical_accuracy: 0.91 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8504 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8499 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8485 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8480 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8475 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8464 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8457 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8455 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8452 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8446 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8435 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8425 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8419 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8409 - sparse_categorical_accuracy: 0.90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.8399 - sparse_categorical_accuracy: 0.9025 - val_loss: 1.7068 - val_sparse_categorical_accuracy: 0.9614 - learning_rate: 1.0000e-04
# Epoch 26/200
# ...
#     365     body_graph.outputs, body_graph.inputs, grads) if grad is not None])
# --> 367 body_grad_graph, args = _create_grad_func(
#     368     ys, xs, non_none_grads, cond_graph, body_graph,
#     369     util.unique_grad_fn_name(body_graph.name), op, maximum_iterations)
#     371 if body_grad_graph.while_op_needs_rewrite:
#     372   # Modify 'op' to output the intermediate accumulators needed by the grad
#     373   # function.
#     374   # NOTE(skyewm): if there are any active sessions, this modification to `op`
#     375   # may make them unrunnable!
#     377   cond_graph.name += "_rewritten"
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/while_v2.py:663, in _create_grad_func(ys, xs, grads, cond_graph, body_graph, name, while_op, maximum_iterations)
#     660 args = [counter, maximum_iterations, total_iters] + list(grads)
#     661 # Note: The returned function does not have `args` in the list of
#     662 # `external_captures`.
# --> 663 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     664     name,
#     665     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     666     args, {},
#     667     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     668                                        maximum_iterations, while_op,
#     669                                        body_graph_inputs, body_graph_outputs))
#     671 # Update the list of outputs with tensors corresponding to the captured
#     672 # tensors. We capture 3 types of tensors when building the grad fn:
#     673 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     676 # 2. Resources, which are output as is.
#     677 # 3. Forward graph loop invariants, which are output as is.
#     678 for external_capture, internal_capture in grad_func_graph.captures:
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/while_v2.py:665, in _create_grad_func.<locals>.<lambda>(*args)
#     660 args = [counter, maximum_iterations, total_iters] + list(grads)
#     661 # Note: The returned function does not have `args` in the list of
#     662 # `external_captures`.
#     663 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     664     name,
# --> 665     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     666     args, {},
#     667     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     668                                        maximum_iterations, while_op,
#     669                                        body_graph_inputs, body_graph_outputs))
#     671 # Update the list of outputs with tensors corresponding to the captured
#     672 # tensors. We capture 3 types of tensors when building the grad fn:
#     673 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     676 # 2. Resources, which are output as is.
#     677 # 3. Forward graph loop invariants, which are output as is.
#     678 for external_capture, internal_capture in grad_func_graph.captures:
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/while_v2.py:720, in _grad_fn(ys, xs, args, func_graph)
#     713 grad_ys = args[3:]
#     715 # Build the gradient graph. Note that this builds the gradient computation of
#     716 # func_graph in the current graph, which requires capturing tensors from
#     717 # func_graph. The captured func_graph tensors are resolved to external tensors
#     718 # after the forward While op has been rewritten in _resolve_grad_captures.
#     719 # TODO(srbs): Mark GradientsHelper as public?
# --> 720 grad_outs = gradients_util._GradientsHelper(
#     721     ys, xs, grad_ys=grad_ys, src_graph=func_graph,
#     722     unconnected_gradients="zero")
#     724 # TODO(b/118712257): Handle the case when grad_outs has None's e.g. when there
#     725 # is a tf.StopGradient in the loop body.
#     726 assert all(g is not None for g in grad_outs)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/gradients_util.py:733, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
# --> 733     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/gradients_util.py:365, in _MaybeCompile(scope, op, func, grad_fn)
#     362     xla_compile = False
#     364 if not xla_compile:
# --> 365   return grad_fn()  # Exit early
#     367 # If the gradients are supposed to be compiled separately, we give them a
#     368 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     369 # they just inherit the existing _XlaScope name, which lets them be merged
#     370 # together with the non-gradient computation.
#     371 if xla_separate_compiled_gradients:
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/gradients_util.py:734, in _GradientsHelper.<locals>.<lambda>()
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
#     733     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/math_grad.py:1716, in _MatMulGrad(op, grad)
#    1714 b = math_ops.conj(op.inputs[1])
#    1715 if not t_a and not t_b:
# -> 1716   grad_a = gen_math_ops.mat_mul(grad, b, transpose_b=True, grad_a=True)
#    1717   grad_b = gen_math_ops.mat_mul(a, grad, transpose_a=True, grad_b=True)
#    1718 elif not t_a and t_b:
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/gen_math_ops.py:6257, in mat_mul(a, b, transpose_a, transpose_b, grad_a, grad_b, name)
#    6255   grad_b = False
#    6256 grad_b = _execute.make_bool(grad_b, "grad_b")
# -> 6257 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6258       "MatMul", a=a, b=b, transpose_a=transpose_a, transpose_b=transpose_b,
#    6259                 grad_a=grad_a, grad_b=grad_b, name=name)
#    6260 _result = _outputs[:]
#    6261 if _execute.must_record_gradient():
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/while_v2.py:1011, in _WhileBodyGradFuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     994 if (op_type in optimized_reduction_ops and
#     995     not util.output_all_intermediates() and
#     996     all(input.graph is self._forward_graph for input in inputs) and
#    (...)
#     999     not util.graph_wrapped_for_higher_order_tape_gradients(
#    1000         self._forward_graph)):
#    1001   return self._move_op_to_forward_graph(
#    1002       op_type,
#    1003       inputs,
#    (...)
#    1008       op_def=op_def,
#    1009       compute_device=compute_device)
# -> 1011 return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#    1012     op_type,
#    1013     inputs,
#    1014     dtypes=dtypes,
#    1015     input_types=input_types,
#    1016     name=name,
#    1017     attrs=attrs,
#    1018     op_def=op_def,
#    1019     compute_device=compute_device)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:668, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     666   if ctxt is not None and hasattr(ctxt, "AddValue"):
#     667     inp = ctxt.AddValue(inp)
# --> 668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
#     670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:675, in FuncGraph.capture(self, tensor, name, shape)
#     674 def capture(self, tensor, name=None, shape=None):
# --> 675   return self._function_captures.capture_by_value(self, tensor, name)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/core/function/capture/capture_container.py:154, in FunctionCaptures.capture_by_value(self, graph, tensor, name)
#     151     name = tensor.op.name
#     152   # cond/while graphs override _capture_helper() so cannot call
#     153   # self.create_placeholder_helper() here directly.
# --> 154   return graph._capture_helper(tensor, name)  # pylint: disable=protected-access
#     155 return tensor
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/while_v2.py:1184, in _WhileBodyGradFuncGraph._capture_helper(self, tensor, name)
#    1181 # Push the intermediate tensor to the tensor list. This captures
#    1182 # `tensor_list`.
#    1183 with self._forward_graph.as_default():
# -> 1184   accumulator = list_ops.tensor_list_push_back(tensor_list, tensor)
#    1185 # Add the modified tensor list to the list of outputs. This output will be
#    1186 # all the accumulated values.
#    1187 self._forward_graph.outputs.append(accumulator)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/ops/gen_list_ops.py:787, in tensor_list_push_back(input_handle, tensor, name)
#     785     pass  # Add nodes to the TensorFlow graph.
#     786 # Add nodes to the TensorFlow graph.
# --> 787 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     788       "TensorListPushBack", input_handle=input_handle, tensor=tensor,
#     789                             name=name)
#     790 _result = _outputs[:]
#     791 if _execute.must_record_gradient():
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:2701, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2698 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2699 # Session.run call cannot occur between creating and mutating the op.
#    2700 with self._mutation_lock():
# -> 2701   ret = Operation.from_node_def(
#    2702       node_def,
#    2703       self,
#    2704       inputs=inputs,
#    2705       output_types=dtypes,
#    2706       control_inputs=control_inputs,
#    2707       input_types=input_types,
#    2708       original_op=self._default_original_op,
#    2709       op_def=op_def,
#    2710   )
#    2711   self._create_op_helper(ret, compute_device=compute_device)
#    2712 return ret
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:1196, in Operation.from_node_def(***failed resolving arguments***)
#    1193     control_input_ops.append(control_op)
#    1195 # Initialize c_op from node_def and other inputs
# -> 1196 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1197 self = Operation(c_op, SymbolicTensor)
#    1198 self._init(g)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/dev/PitchPredict/pitch_predict/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:1049, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1046   serialized = attr_value.SerializeToString()
#    1047   # TODO(skyewm): this creates and deletes a new TF_Status for every attr.
#    1048   # It might be worth creating a convenient way to re-use the same status.
# -> 1049   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1050                                          serialized)
#    1052 try:
#    1053   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#
# KeyboardInterrupt:
