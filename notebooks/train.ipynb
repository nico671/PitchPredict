# %%
import logging
import os
import pickle
import sys
import time
from pathlib import Path
from statistics import mean

import numpy as np
import polars as pl
import yaml
from sklearn.calibration import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
from pathlib import Path

import numpy as np
import tensorflow as tf
import yaml

from dvclive import Live
from dvclive.keras import DVCLiveCallback

params = Path("../params.yaml")
with open(params, "r") as file:
    params = yaml.safe_load(file)
DROPOUT = params["train"]["dropout"]
PATIENCE = params["train"]["patience"]
KERN_REG = params["train"]["kernel_regularizer"]
BATCH_NORMALIZATION = params["train"]["batch_normalization"]
BATCH_SIZE = params["train"]["batch_size"]
EPOCHS = params["train"]["epochs"]
LSTM_UNITS = params["train"]["lstm_units"]


def compile_and_fit(model, X_train, y_train, X_val, y_val, pitcher_name):
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=1e-4,  # - learning_rate: controls how much to change the model in response to the estimated error each time the model weights are updated.
        clipnorm=1.0,  # - clipnorm: clips gradients by norm; helps prevent exploding gradients.
        weight_decay=1e-4,  # - weight_decay: adds a penalty to the loss function to prevent overfitting.
    )
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["sparse_categorical_accuracy"],
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_sparse_categorical_accuracy",
            patience=PATIENCE,
            restore_best_weights=True,
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.2,
            patience=PATIENCE,
            min_lr=1e-6,
        ),
        DVCLiveCallback(live=Live(f"dvclive/{pitcher_name}_logs")),
    ]

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
    )

    return history


def create_model(input_shape, num_classes):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(shape=input_shape))
    model.add(
        tf.keras.layers.LSTM(
            LSTM_UNITS,
            return_sequences=True,
            dropout=DROPOUT,
            kernel_regularizer=tf.keras.regularizers.l2(KERN_REG),
        )
    )
    if BATCH_NORMALIZATION:
        model.add(tf.keras.layers.BatchNormalization())
    model.add(
        tf.keras.layers.LSTM(
            LSTM_UNITS,
            return_sequences=True,
            dropout=DROPOUT,
            kernel_regularizer=tf.keras.regularizers.l2(KERN_REG),
        )
    )
    if BATCH_NORMALIZATION:
        model.add(tf.keras.layers.BatchNormalization())
    model.add(
        tf.keras.layers.LSTM(
            LSTM_UNITS,
            dropout=DROPOUT,
            kernel_regularizer=tf.keras.regularizers.l2(KERN_REG),
        )
    )
    if BATCH_NORMALIZATION:
        model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dense(num_classes, activation="softmax"))
    return model


def calculate_class_weights(y):
    proportions = np.bincount(y) / len(y)
    for i, proportion in enumerate(proportions):
        if proportion == 0:
            proportions[i] = 1e-6
    inverseN = 1 / len(proportions)
    weights = [inverseN / proportion for proportion in proportions]
    return {i: w for i, w in enumerate(weights)}

# %%
df = pl.read_parquet(Path("../" + params["train"]["input_data_path"]))

# %%
logger = logging.getLogger("choo choo")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setFormatter(
    logging.Formatter("%(asctime)s - %(name)s - %(levelname)s - %(message)s")
)
logger.addHandler(handler)

# %%
def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X[i : (i + time_steps)]
        Xs.append(v)
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
def create_training_data(pitcher_df, features):
    # sort the data by game_date, game_pk, at_bat_number, pitch_number
    pitcher_df = pitcher_df.sort(
        [
            "game_date",
            "game_pk",
            "at_bat_number",
            "pitch_number",
        ],
        descending=False,
    )

    # select features and target variable for initial split of X and y
    X = pitcher_df.select(pl.col(features)).to_numpy()
    y = pitcher_df.select(pl.col("next_pitch")).to_numpy().ravel()

    # encode target variable
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    y = y_encoded

    # declare time steps
    params_path = Path("../params.yaml")
    with open(params_path, "r") as file:
        params = yaml.safe_load(file)

    time_steps = params["train"]["time_steps"]

    X_seq, y_seq = create_sequences(X, y, time_steps)
    # convert to correct datatypes for model
    X_seq = X_seq.astype("float32")
    y_seq = y_seq.astype("int32")  # Ensure labels are integers

    # split into train, test, val
    train_split = params["train"]["train_split"]
    train_size = int(len(X_seq) * train_split)
    val_size = int(len(X_seq) * (1 - train_split) / 2)
    X_train, X_val, X_test = np.split(X_seq, [train_size, train_size + val_size])
    y_train, y_val, y_test = np.split(y_seq, [train_size, train_size + val_size])

    # scale features, no reason for minmax tbh, just read a stackoverflow that recommended it
    scaler = MinMaxScaler()
    n_samples, n_timesteps, n_features = X_train.shape
    X_train_reshaped = X_train.reshape(-1, n_features)
    X_train_scaled = scaler.fit_transform(X_train_reshaped)
    X_train_scaled = X_train_scaled.reshape(n_samples, n_timesteps, n_features)
    X_val_scaled = scaler.transform(X_val.reshape(-1, n_features)).reshape(X_val.shape)
    X_test_scaled = scaler.transform(X_test.reshape(-1, n_features)).reshape(
        X_test.shape
    )

    # logger.info("Unique labels in y_train:", list(np.unique(y_train)))
    # logger.info("Unique labels in y_val:", list(np.unique(y_val)))
    # logger.info("Unique labels in y_test:", list(np.unique(y_test)))

    return (
        X_train_scaled,
        y_train,
        X_val_scaled,
        y_val,
        X_test_scaled,
        y_test,
        label_encoder,
    )

# %%
def training_loop(df, params):
    pitcher_data = {}
    count = 0
    features = df.columns
    for feature in [
        "next_pitch",
        "pitcher",
        "player_name",
        "game_date",
        "game_pk",
        "pitch_type",
        "type",
    ]:
        features.remove(feature)
    start_time = time.time()
    for pitcher_df in df.group_by("pitcher"):
        pitcher_code = pitcher_df[0]
        pitcher_df = pitcher_df[1]

        pitcher_name = pitcher_df.select(pl.first("player_name")).item()
        num_pitches = len(pitcher_df)
        logger.info(
            f"Training model for pitcher: {pitcher_name} - {num_pitches} pitches"
        )
        X_train, y_train, X_val, y_val, X_test, y_test, label_encoder = (
            create_training_data(pitcher_df, features)
        )

        lstm_model = create_model(X_train.shape[1:], len(label_encoder.classes_))
        history = compile_and_fit(
            lstm_model,
            X_train,
            y_train,
            X_val,
            y_val,
            pitcher_name,
        )
        most_common_pitch_rate = pitcher_df.select(
            pl.col("pitch_type").value_counts().sort(descending=False).head(1)
        ).item()["count"] / len(pitcher_df)

        print(f"Most common pitch rate for {pitcher_name}: {most_common_pitch_rate}")
        test_loss, test_accuracy = lstm_model.evaluate(X_test, y_test)
        pitcher_data[pitcher_code] = {
            "model": lstm_model,
            "history": history,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "total_pitches": len(y_test) + len(y_train) + len(y_val),
            "unique_classes": len(np.unique(y_train)),
            "player_name": pitcher_name,
            "X_test": X_test,
            "y_test": y_test,
            "label_encoder": label_encoder,
            "most_common_pitch_rate": most_common_pitch_rate,
            "performance_gain": (test_accuracy - most_common_pitch_rate) * 100,
        }
        logger.info(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}")
        logger.info(
            f" Accuracy Gained over guessing most common pitch for {pitcher_name}: {pitcher_data[pitcher_code]["performance_gain"]:.2f}%",
        )
        logger.info(
            f"Average Test Accuracy: {mean([pitcher_data[pitcher]['test_accuracy'] for pitcher in pitcher_data])*100:.2f}%"
        )

        logger.info(
            f"Average Performance Gained over guessing most common pitch: {mean([pitcher_data[pitcher]['performance_gain'] for pitcher in pitcher_data]):.2f}%"
        )

        count += 1
        logger.info(
            f'{count} of {len(df.select(pl.col("pitcher")).unique())}, {(count/len(df.select(pl.col("pitcher")).unique())) * 100:.2f}% done!'
        )
    end_time = time.time()
    logger.info(f"Training took {end_time - start_time} seconds")
    return pitcher_data

# %%
pitcher_data = training_loop(df, params)
# Out:
# 2024-12-31 20:04:02,603 - choo choo - INFO - Training model for pitcher: Scherzer, Max - 27260 pitches
# 2024-12-31 20:04:02,603 - choo choo - INFO - Training model for pitcher: Scherzer, Max - 27260 pitches
# Epoch 1/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 15:02 3s/step - loss: 4.1576 - sparse_categorical_accuracy: 0.093 ━━━━━━━━━━━━━━━━━━━━ 30s 103ms/step - loss: 4.1133 - sparse_categorical_accuracy: 0.10 ━━━━━━━━━━━━━━━━━━━━ 30s 102ms/step - loss: 4.0777 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - loss: 4.0641 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - loss: 4.0503 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 29s 102ms/step - loss: 4.0398 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 29s 102ms/step - loss: 4.0342 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - loss: 4.0263 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - loss: 4.0219 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 28s 100ms/step - loss: 4.0142 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - loss: 4.0066 - sparse_categorical_accuracy: 0.1157 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - loss: 4.0003 - sparse_categorical_accuracy: 0.116 ━━━━━━━━━━━━━━━━━━━━ 28s 100ms/step - loss: 3.9948 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - loss: 3.9900 - sparse_categorical_accuracy: 0.1170 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - loss: 3.9844 - sparse_categorical_accuracy: 0.117 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9790 - sparse_categorical_accuracy: 0.118 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9741 - sparse_categorical_accuracy: 0.119 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9695 - sparse_categorical_accuracy: 0.119 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9658 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 27s 98ms/step - loss: 3.9622 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9588 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9554 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9524 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9497 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - loss: 3.9472 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 3.9448 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - loss: 3.9423 - sparse_categorical_accuracy: 0.120 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9400 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9380 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9361 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9340 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9321 - sparse_categorical_accuracy: 0.12 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9303 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9287 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9272 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9258 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - loss: 3.9244 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 101ms/step - loss: 3.9229 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 102ms/step - loss: 3.9213 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 102ms/step - loss: 3.9198 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 102ms/step - loss: 3.9183 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 26s 102ms/step - loss: 3.9168 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 25s 102ms/step - loss: 3.9153 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 25s 102ms/step - loss: 3.9138 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 25s 102ms/step - loss: 3.9124 - sparse_categorical_accuracy: 0.11 ━━━━━━━━━━━━━━━━━━━━ 25s 102ms/step - loss: 3.9109 - sparse_categorical_acc ...
# Epoch 2/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 1:15 255ms/step - loss: 3.1741 - sparse_categorical_accuracy: 0.125 ━━━━━━━━━━━━━━━━━━━━ 1:50 373ms/step - loss: 3.1396 - sparse_categorical_accuracy: 0.140 ━━━━━━━━━━━━━━━━━━━━ 1:18 266ms/step - loss: 3.1573 - sparse_categorical_accuracy: 0.147 ━━━━━━━━━━━━━━━━━━━━ 1:06 226ms/step - loss: 3.1572 - sparse_categorical_accuracy: 0.158 ━━━━━━━━━━━━━━━━━━━━ 1:00 206ms/step - loss: 3.1612 - sparse_categorical_accuracy: 0.164 ━━━━━━━━━━━━━━━━━━━━ 55s 190ms/step - loss: 3.1643 - sparse_categorical_accuracy: 0.168 ━━━━━━━━━━━━━━━━━━━━ 52s 180ms/step - loss: 3.1652 - sparse_categorical_accuracy: 0.17 ━━━━━━━━━━━━━━━━━━━━ 51s 176ms/step - loss: 3.1623 - sparse_categorical_accuracy: 0.17 ━━━━━━━━━━━━━━━━━━━━ 49s 170ms/step - loss: 3.1606 - sparse_categorical_accuracy: 0.17 ━━━━━━━━━━━━━━━━━━━━ 49s 171ms/step - loss: 3.1592 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 47s 167ms/step - loss: 3.1580 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 47s 164ms/step - loss: 3.1564 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 3.1567 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 45s 161ms/step - loss: 3.1572 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 45s 159ms/step - loss: 3.1582 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 3.1592 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - loss: 3.1601 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 42s 152ms/step - loss: 3.1605 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 41s 150ms/step - loss: 3.1610 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 41s 148ms/step - loss: 3.1619 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 40s 146ms/step - loss: 3.1624 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 39s 145ms/step - loss: 3.1626 - sparse_categorical_accuracy: 0.18 ━━━━━━━━━━━━━━━━━━━━ 39s 143ms/step - loss: 3.1627 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 39s 144ms/step - loss: 3.1634 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 38s 142ms/step - loss: 3.1639 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 38s 141ms/step - loss: 3.1644 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 38s 141ms/step - loss: 3.1648 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 37s 140ms/step - loss: 3.1652 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 37s 139ms/step - loss: 3.1655 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 37s 139ms/step - loss: 3.1658 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 36s 138ms/step - loss: 3.1661 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 36s 137ms/step - loss: 3.1665 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 36s 136ms/step - loss: 3.1669 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 35s 135ms/step - loss: 3.1672 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 35s 134ms/step - loss: 3.1675 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 34s 133ms/step - loss: 3.1677 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 34s 133ms/step - loss: 3.1679 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 34s 132ms/step - loss: 3.1678 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 34s 132ms/step - loss: 3.1677 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 34s 132ms/step - loss: 3.1677 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 33s 131ms/step - loss: 3.1678 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 33s 131ms/step - loss: 3.1677 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 33s 130ms/step - loss: 3.1678 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 32s 130ms/step - loss: 3.1678 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 32s 130ms/step - loss: 3.1678 - sparse_categorical_accuracy: 0.19 ━━━━━━━━━━━━━━━━━━━━ 32s 129ms/step - loss: 3.1678 - sparse_catego ...
# Epoch 3/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 163ms/step - loss: 2.8197 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 2:04 419ms/step - loss: 2.7719 - sparse_categorical_accuracy: 0.339 ━━━━━━━━━━━━━━━━━━━━ 1:34 322ms/step - loss: 2.7586 - sparse_categorical_accuracy: 0.349 ━━━━━━━━━━━━━━━━━━━━ 1:22 281ms/step - loss: 2.7598 - sparse_categorical_accuracy: 0.348 ━━━━━━━━━━━━━━━━━━━━ 1:11 245ms/step - loss: 2.7671 - sparse_categorical_accuracy: 0.345 ━━━━━━━━━━━━━━━━━━━━ 1:04 222ms/step - loss: 2.7713 - sparse_categorical_accuracy: 0.343 ━━━━━━━━━━━━━━━━━━━━ 59s 205ms/step - loss: 2.7743 - sparse_categorical_accuracy: 0.340 ━━━━━━━━━━━━━━━━━━━━ 57s 197ms/step - loss: 2.7792 - sparse_categorical_accuracy: 0.33 ━━━━━━━━━━━━━━━━━━━━ 54s 189ms/step - loss: 2.7838 - sparse_categorical_accuracy: 0.33 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - loss: 2.7869 - sparse_categorical_accuracy: 0.33 ━━━━━━━━━━━━━━━━━━━━ 51s 180ms/step - loss: 2.7910 - sparse_categorical_accuracy: 0.32 ━━━━━━━━━━━━━━━━━━━━ 49s 174ms/step - loss: 2.7939 - sparse_categorical_accuracy: 0.32 ━━━━━━━━━━━━━━━━━━━━ 48s 171ms/step - loss: 2.7965 - sparse_categorical_accuracy: 0.32 ━━━━━━━━━━━━━━━━━━━━ 47s 166ms/step - loss: 2.7988 - sparse_categorical_accuracy: 0.32 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 2.8004 - sparse_categorical_accuracy: 0.32 ━━━━━━━━━━━━━━━━━━━━ 45s 160ms/step - loss: 2.8023 - sparse_categorical_accuracy: 0.32 ━━━━━━━━━━━━━━━━━━━━ 44s 158ms/step - loss: 2.8038 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - loss: 2.8051 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 44s 158ms/step - loss: 2.8063 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 43s 158ms/step - loss: 2.8071 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 43s 158ms/step - loss: 2.8083 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 42s 156ms/step - loss: 2.8097 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 42s 154ms/step - loss: 2.8109 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - loss: 2.8118 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 41s 151ms/step - loss: 2.8125 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - loss: 2.8132 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 40s 149ms/step - loss: 2.8138 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - loss: 2.8143 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - loss: 2.8147 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 38s 145ms/step - loss: 2.8149 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 38s 143ms/step - loss: 2.8151 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 37s 142ms/step - loss: 2.8151 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 37s 141ms/step - loss: 2.8151 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 37s 140ms/step - loss: 2.8152 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 36s 140ms/step - loss: 2.8152 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 36s 140ms/step - loss: 2.8152 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 36s 139ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 36s 139ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 36s 140ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 36s 140ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - loss: 2.8153 - sparse_categorical_accuracy: 0.31 ━━━━━━━━━━━━━━━━━━━━ 34s 138ms/step - loss: 2.8152 - sparse_catego ...
# Epoch 4/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 39s 133ms/step - loss: 2.6401 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 2:04 422ms/step - loss: 2.6128 - sparse_categorical_accuracy: 0.410 ━━━━━━━━━━━━━━━━━━━━ 1:37 330ms/step - loss: 2.6161 - sparse_categorical_accuracy: 0.401 ━━━━━━━━━━━━━━━━━━━━ 1:23 284ms/step - loss: 2.6162 - sparse_categorical_accuracy: 0.396 ━━━━━━━━━━━━━━━━━━━━ 1:16 260ms/step - loss: 2.6172 - sparse_categorical_accuracy: 0.393 ━━━━━━━━━━━━━━━━━━━━ 1:09 239ms/step - loss: 2.6151 - sparse_categorical_accuracy: 0.393 ━━━━━━━━━━━━━━━━━━━━ 1:09 239ms/step - loss: 2.6100 - sparse_categorical_accuracy: 0.394 ━━━━━━━━━━━━━━━━━━━━ 1:05 227ms/step - loss: 2.6061 - sparse_categorical_accuracy: 0.395 ━━━━━━━━━━━━━━━━━━━━ 1:04 223ms/step - loss: 2.6037 - sparse_categorical_accuracy: 0.396 ━━━━━━━━━━━━━━━━━━━━ 1:02 216ms/step - loss: 2.6018 - sparse_categorical_accuracy: 0.398 ━━━━━━━━━━━━━━━━━━━━ 59s 209ms/step - loss: 2.6006 - sparse_categorical_accuracy: 0.398 ━━━━━━━━━━━━━━━━━━━━ 1:00 211ms/step - loss: 2.5988 - sparse_categorical_accuracy: 0.398 ━━━━━━━━━━━━━━━━━━━━ 59s 210ms/step - loss: 2.5962 - sparse_categorical_accuracy: 0.399 ━━━━━━━━━━━━━━━━━━━━ 57s 204ms/step - loss: 2.5949 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 55s 197ms/step - loss: 2.5944 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 54s 193ms/step - loss: 2.5939 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 53s 191ms/step - loss: 2.5930 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 52s 187ms/step - loss: 2.5927 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 50s 182ms/step - loss: 2.5924 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 49s 178ms/step - loss: 2.5914 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 48s 175ms/step - loss: 2.5906 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 48s 175ms/step - loss: 2.5899 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 48s 175ms/step - loss: 2.5894 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 47s 174ms/step - loss: 2.5889 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 46s 171ms/step - loss: 2.5885 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 46s 169ms/step - loss: 2.5883 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 45s 167ms/step - loss: 2.5879 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 44s 165ms/step - loss: 2.5875 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 43s 163ms/step - loss: 2.5871 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 43s 161ms/step - loss: 2.5872 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 42s 160ms/step - loss: 2.5874 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 42s 158ms/step - loss: 2.5877 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 41s 157ms/step - loss: 2.5878 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - loss: 2.5880 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 40s 154ms/step - loss: 2.5881 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 2.5881 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 39s 152ms/step - loss: 2.5880 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 39s 151ms/step - loss: 2.5880 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - loss: 2.5879 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 38s 149ms/step - loss: 2.5879 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 38s 149ms/step - loss: 2.5878 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 37s 148ms/step - loss: 2.5877 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 37s 147ms/step - loss: 2.5876 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 37s 147ms/step - loss: 2.5874 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 36s 146ms/step - loss: 2.5872 - sparse_categorical_accuracy: 0.40 ━━━━━━━━━━━━━━━━━━━━ 36s 146ms/step - loss: 2.5870 - sp ...
# Epoch 5/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 49s 167ms/step - loss: 2.2704 - sparse_categorical_accuracy: 0.48 ━━━━━━━━━━━━━━━━━━━━ 1:26 292ms/step - loss: 2.2999 - sparse_categorical_accuracy: 0.468 ━━━━━━━━━━━━━━━━━━━━ 1:09 235ms/step - loss: 2.3304 - sparse_categorical_accuracy: 0.458 ━━━━━━━━━━━━━━━━━━━━ 1:01 211ms/step - loss: 2.3433 - sparse_categorical_accuracy: 0.458 ━━━━━━━━━━━━━━━━━━━━ 56s 194ms/step - loss: 2.3454 - sparse_categorical_accuracy: 0.460 ━━━━━━━━━━━━━━━━━━━━ 52s 181ms/step - loss: 2.3487 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 51s 177ms/step - loss: 2.3542 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 51s 177ms/step - loss: 2.3609 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 52s 183ms/step - loss: 2.3680 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 50s 177ms/step - loss: 2.3738 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 49s 173ms/step - loss: 2.3769 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 48s 169ms/step - loss: 2.3784 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 47s 166ms/step - loss: 2.3796 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 46s 164ms/step - loss: 2.3804 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 45s 161ms/step - loss: 2.3811 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 46s 164ms/step - loss: 2.3815 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 45s 162ms/step - loss: 2.3824 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 44s 160ms/step - loss: 2.3837 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 43s 158ms/step - loss: 2.3844 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - loss: 2.3852 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - loss: 2.3857 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - loss: 2.3862 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 42s 154ms/step - loss: 2.3867 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 41s 153ms/step - loss: 2.3872 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - loss: 2.3876 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - loss: 2.3880 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - loss: 2.3882 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - loss: 2.3884 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 39s 149ms/step - loss: 2.3885 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - loss: 2.3888 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - loss: 2.3890 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - loss: 2.3891 - sparse_categorical_accuracy: 0.45 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - loss: 2.3892 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - loss: 2.3895 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 38s 145ms/step - loss: 2.3898 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - loss: 2.3904 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - loss: 2.3909 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - loss: 2.3912 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - loss: 2.3916 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 36s 143ms/step - loss: 2.3918 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 36s 143ms/step - loss: 2.3920 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 36s 142ms/step - loss: 2.3924 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 35s 141ms/step - loss: 2.3926 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - loss: 2.3928 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - loss: 2.3931 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - loss: 2.3935 - sparse_categorica ...
# Epoch 6/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 1:58 400ms/step - loss: 2.5070 - sparse_categorical_accuracy: 0.437 ━━━━━━━━━━━━━━━━━━━━ 1:35 324ms/step - loss: 2.4537 - sparse_categorical_accuracy: 0.449 ━━━━━━━━━━━━━━━━━━━━ 1:27 296ms/step - loss: 2.4059 - sparse_categorical_accuracy: 0.462 ━━━━━━━━━━━━━━━━━━━━ 1:14 254ms/step - loss: 2.3870 - sparse_categorical_accuracy: 0.466 ━━━━━━━━━━━━━━━━━━━━ 1:06 228ms/step - loss: 2.3846 - sparse_categorical_accuracy: 0.465 ━━━━━━━━━━━━━━━━━━━━ 1:02 214ms/step - loss: 2.3869 - sparse_categorical_accuracy: 0.462 ━━━━━━━━━━━━━━━━━━━━ 59s 204ms/step - loss: 2.3850 - sparse_categorical_accuracy: 0.463 ━━━━━━━━━━━━━━━━━━━━ 1:00 208ms/step - loss: 2.3824 - sparse_categorical_accuracy: 0.464 ━━━━━━━━━━━━━━━━━━━━ 57s 197ms/step - loss: 2.3802 - sparse_categorical_accuracy: 0.464 ━━━━━━━━━━━━━━━━━━━━ 56s 195ms/step - loss: 2.3780 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 54s 190ms/step - loss: 2.3753 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 52s 185ms/step - loss: 2.3727 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 51s 182ms/step - loss: 2.3697 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 51s 181ms/step - loss: 2.3681 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 50s 179ms/step - loss: 2.3663 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - loss: 2.3643 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 48s 173ms/step - loss: 2.3621 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 47s 170ms/step - loss: 2.3602 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 46s 167ms/step - loss: 2.3586 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 46s 168ms/step - loss: 2.3569 - sparse_categorical_accuracy: 0.46 ━━━━━━━━━━━━━━━━━━━━ 45s 166ms/step - loss: 2.3556 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 45s 164ms/step - loss: 2.3542 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 44s 162ms/step - loss: 2.3528 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - loss: 2.3517 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 43s 159ms/step - loss: 2.3508 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 42s 157ms/step - loss: 2.3500 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 42s 156ms/step - loss: 2.3495 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - loss: 2.3489 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - loss: 2.3480 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - loss: 2.3475 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 2.3468 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 2.3461 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 40s 152ms/step - loss: 2.3456 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 39s 151ms/step - loss: 2.3453 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 39s 150ms/step - loss: 2.3449 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 39s 151ms/step - loss: 2.3443 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 39s 150ms/step - loss: 2.3438 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 38s 149ms/step - loss: 2.3434 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 38s 148ms/step - loss: 2.3429 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 38s 148ms/step - loss: 2.3423 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 37s 147ms/step - loss: 2.3418 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.3413 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.3409 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.3407 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 36s 146ms/step - loss: 2.3403 - sparse_categorical_accuracy: 0.47 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.3401 - sparse_c ...
# Epoch 7/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 162ms/step - loss: 2.4417 - sparse_categorical_accuracy: 0.39 ━━━━━━━━━━━━━━━━━━━━ 39s 133ms/step - loss: 2.4096 - sparse_categorical_accuracy: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:08 232ms/step - loss: 2.3814 - sparse_categorical_accuracy: 0.442 ━━━━━━━━━━━━━━━━━━━━ 1:20 274ms/step - loss: 2.3586 - sparse_categorical_accuracy: 0.458 ━━━━━━━━━━━━━━━━━━━━ 1:12 248ms/step - loss: 2.3399 - sparse_categorical_accuracy: 0.468 ━━━━━━━━━━━━━━━━━━━━ 1:08 234ms/step - loss: 2.3246 - sparse_categorical_accuracy: 0.476 ━━━━━━━━━━━━━━━━━━━━ 1:04 222ms/step - loss: 2.3146 - sparse_categorical_accuracy: 0.480 ━━━━━━━━━━━━━━━━━━━━ 1:01 213ms/step - loss: 2.3078 - sparse_categorical_accuracy: 0.485 ━━━━━━━━━━━━━━━━━━━━ 58s 203ms/step - loss: 2.3040 - sparse_categorical_accuracy: 0.487 ━━━━━━━━━━━━━━━━━━━━ 59s 207ms/step - loss: 2.2998 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 57s 201ms/step - loss: 2.2985 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 55s 193ms/step - loss: 2.2966 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 55s 193ms/step - loss: 2.2941 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 53s 188ms/step - loss: 2.2927 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 51s 183ms/step - loss: 2.2908 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 50s 177ms/step - loss: 2.2886 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 48s 174ms/step - loss: 2.2870 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 48s 175ms/step - loss: 2.2860 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 48s 173ms/step - loss: 2.2853 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 47s 172ms/step - loss: 2.2845 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 46s 170ms/step - loss: 2.2838 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 46s 167ms/step - loss: 2.2832 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 45s 165ms/step - loss: 2.2824 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 44s 163ms/step - loss: 2.2821 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - loss: 2.2821 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 43s 161ms/step - loss: 2.2820 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 43s 159ms/step - loss: 2.2820 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 42s 157ms/step - loss: 2.2817 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 41s 156ms/step - loss: 2.2812 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 41s 156ms/step - loss: 2.2807 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - loss: 2.2801 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 40s 154ms/step - loss: 2.2796 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 2.2789 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 40s 152ms/step - loss: 2.2782 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 39s 151ms/step - loss: 2.2777 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 39s 150ms/step - loss: 2.2772 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 38s 149ms/step - loss: 2.2768 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 38s 148ms/step - loss: 2.2765 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 38s 149ms/step - loss: 2.2762 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 38s 148ms/step - loss: 2.2759 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 38s 148ms/step - loss: 2.2757 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 37s 147ms/step - loss: 2.2754 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 37s 147ms/step - loss: 2.2751 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.2748 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.2743 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.2740 - sparse_cate ...
# Epoch 8/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 2:04 421ms/step - loss: 2.0621 - sparse_categorical_accuracy: 0.546 ━━━━━━━━━━━━━━━━━━━━ 1:21 276ms/step - loss: 2.0712 - sparse_categorical_accuracy: 0.531 ━━━━━━━━━━━━━━━━━━━━ 1:03 216ms/step - loss: 2.0688 - sparse_categorical_accuracy: 0.534 ━━━━━━━━━━━━━━━━━━━━ 59s 204ms/step - loss: 2.0608 - sparse_categorical_accuracy: 0.539 ━━━━━━━━━━━━━━━━━━━━ 1:01 210ms/step - loss: 2.0581 - sparse_categorical_accuracy: 0.542 ━━━━━━━━━━━━━━━━━━━━ 57s 198ms/step - loss: 2.0645 - sparse_categorical_accuracy: 0.542 ━━━━━━━━━━━━━━━━━━━━ 55s 190ms/step - loss: 2.0710 - sparse_categorical_accuracy: 0.54 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - loss: 2.0782 - sparse_categorical_accuracy: 0.54 ━━━━━━━━━━━━━━━━━━━━ 52s 182ms/step - loss: 2.0862 - sparse_categorical_accuracy: 0.54 ━━━━━━━━━━━━━━━━━━━━ 52s 181ms/step - loss: 2.0920 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 52s 183ms/step - loss: 2.0982 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 50s 178ms/step - loss: 2.1028 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - loss: 2.1066 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 48s 171ms/step - loss: 2.1096 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 47s 167ms/step - loss: 2.1124 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 47s 170ms/step - loss: 2.1149 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 48s 172ms/step - loss: 2.1174 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 47s 169ms/step - loss: 2.1193 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 46s 168ms/step - loss: 2.1208 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 46s 166ms/step - loss: 2.1223 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 45s 166ms/step - loss: 2.1241 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 45s 164ms/step - loss: 2.1253 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 44s 163ms/step - loss: 2.1268 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - loss: 2.1280 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 43s 160ms/step - loss: 2.1290 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 43s 162ms/step - loss: 2.1301 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 43s 160ms/step - loss: 2.1312 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 42s 159ms/step - loss: 2.1326 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 42s 158ms/step - loss: 2.1338 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 42s 157ms/step - loss: 2.1349 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 41s 157ms/step - loss: 2.1359 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 41s 156ms/step - loss: 2.1368 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 41s 157ms/step - loss: 2.1377 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 41s 156ms/step - loss: 2.1386 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 40s 156ms/step - loss: 2.1397 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 40s 155ms/step - loss: 2.1407 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 40s 154ms/step - loss: 2.1415 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 40s 155ms/step - loss: 2.1423 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 39s 154ms/step - loss: 2.1431 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 39s 154ms/step - loss: 2.1440 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 39s 153ms/step - loss: 2.1447 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - loss: 2.1453 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 38s 153ms/step - loss: 2.1459 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - loss: 2.1466 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 2.1472 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - loss: 2.1478 - sparse_categor ...
# Epoch 9/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 1:06 223ms/step - loss: 2.1102 - sparse_categorical_accuracy: 0.500 ━━━━━━━━━━━━━━━━━━━━ 1:04 219ms/step - loss: 2.1192 - sparse_categorical_accuracy: 0.503 ━━━━━━━━━━━━━━━━━━━━ 57s 196ms/step - loss: 2.1240 - sparse_categorical_accuracy: 0.497 ━━━━━━━━━━━━━━━━━━━━ 59s 204ms/step - loss: 2.1291 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 54s 186ms/step - loss: 2.1340 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 52s 179ms/step - loss: 2.1317 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 51s 176ms/step - loss: 2.1296 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 50s 173ms/step - loss: 2.1288 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 49s 172ms/step - loss: 2.1269 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 48s 168ms/step - loss: 2.1259 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 48s 169ms/step - loss: 2.1244 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 47s 167ms/step - loss: 2.1238 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 2.1234 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 45s 159ms/step - loss: 2.1227 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 44s 157ms/step - loss: 2.1231 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - loss: 2.1234 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - loss: 2.1239 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 42s 152ms/step - loss: 2.1248 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - loss: 2.1251 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 42s 154ms/step - loss: 2.1254 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 42s 153ms/step - loss: 2.1256 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - loss: 2.1261 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 151ms/step - loss: 2.1264 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 150ms/step - loss: 2.1269 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - loss: 2.1274 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 151ms/step - loss: 2.1278 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - loss: 2.1280 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 40s 149ms/step - loss: 2.1281 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 39s 148ms/step - loss: 2.1281 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 39s 148ms/step - loss: 2.1282 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - loss: 2.1285 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 148ms/step - loss: 2.1289 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - loss: 2.1293 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - loss: 2.1296 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - loss: 2.1298 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - loss: 2.1301 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 145ms/step - loss: 2.1303 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.1305 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 145ms/step - loss: 2.1306 - sparse_categorical_accuracy: 0.49 ━━━━━━━━━━━━━━━━━━━━ 37s 145ms/step - loss: 2.1306 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - loss: 2.1306 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 143ms/step - loss: 2.1305 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 143ms/step - loss: 2.1304 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 143ms/step - loss: 2.1302 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 143ms/step - loss: 2.1300 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 35s 143ms/step - loss: 2.1300 - sparse_categorical_ ...
# Epoch 10/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 1:22 277ms/step - loss: 2.0158 - sparse_categorical_accuracy: 0.531 ━━━━━━━━━━━━━━━━━━━━ 1:40 341ms/step - loss: 1.9995 - sparse_categorical_accuracy: 0.546 ━━━━━━━━━━━━━━━━━━━━ 1:15 256ms/step - loss: 2.0043 - sparse_categorical_accuracy: 0.550 ━━━━━━━━━━━━━━━━━━━━ 1:05 221ms/step - loss: 2.0158 - sparse_categorical_accuracy: 0.548 ━━━━━━━━━━━━━━━━━━━━ 59s 204ms/step - loss: 2.0285 - sparse_categorical_accuracy: 0.543 ━━━━━━━━━━━━━━━━━━━━ 56s 192ms/step - loss: 2.0399 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 56s 196ms/step - loss: 2.0491 - sparse_categorical_accuracy: 0.53 ━━━━━━━━━━━━━━━━━━━━ 54s 189ms/step - loss: 2.0559 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - loss: 2.0598 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 52s 182ms/step - loss: 2.0633 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 51s 179ms/step - loss: 2.0659 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - loss: 2.0679 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 50s 176ms/step - loss: 2.0701 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 48s 171ms/step - loss: 2.0717 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 47s 167ms/step - loss: 2.0734 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 45s 163ms/step - loss: 2.0752 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 45s 162ms/step - loss: 2.0774 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 46s 166ms/step - loss: 2.0789 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 45s 163ms/step - loss: 2.0804 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - loss: 2.0813 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 43s 159ms/step - loss: 2.0821 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 43s 157ms/step - loss: 2.0833 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - loss: 2.0847 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 42s 157ms/step - loss: 2.0859 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - loss: 2.0872 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 153ms/step - loss: 2.0883 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - loss: 2.0890 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - loss: 2.0893 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - loss: 2.0896 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 40s 152ms/step - loss: 2.0897 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - loss: 2.0897 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - loss: 2.0897 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 149ms/step - loss: 2.0897 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 149ms/step - loss: 2.0898 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 149ms/step - loss: 2.0900 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 39s 149ms/step - loss: 2.0901 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 38s 148ms/step - loss: 2.0902 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 38s 147ms/step - loss: 2.0903 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 38s 147ms/step - loss: 2.0904 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.0906 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.0908 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.0909 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 37s 146ms/step - loss: 2.0911 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.0912 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.0913 - sparse_categorical_accuracy: 0.50 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - loss: 2.0914 - sparse_categori ...
# Epoch 11/200
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 161ms/step - loss: 1.9809 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 2:19 472ms/step - loss: 1.9967 - sparse_categorical_accuracy: 0.523 ━━━━━━━━━━━━━━━━━━━━ 1:39 337ms/step - loss: 1.9957 - sparse_categorical_accuracy: 0.529 ━━━━━━━━━━━━━━━━━━━━ 1:24 287ms/step - loss: 2.0016 - sparse_categorical_accuracy: 0.529 ━━━━━━━━━━━━━━━━━━━━ 1:15 258ms/step - loss: 2.0073 - sparse_categorical_accuracy: 0.530 ━━━━━━━━━━━━━━━━━━━━ 1:08 235ms/step - loss: 2.0169 - sparse_categorical_accuracy: 0.527 ━━━━━━━━━━━━━━━━━━━━ 1:06 229ms/step - loss: 2.0201 - sparse_categorical_accuracy: 0.526 ━━━━━━━━━━━━━━━━━━━━ 1:03 219ms/step - loss: 2.0207 - sparse_categorical_accuracy: 0.526 ━━━━━━━━━━━━━━━━━━━━ 1:00 211ms/step - loss: 2.0224 - sparse_categorical_accuracy: 0.525 ━━━━━━━━━━━━━━━━━━━━ 59s 206ms/step - loss: 2.0258 - sparse_categorical_accuracy: 0.524 ━━━━━━━━━━━━━━━━━━━━ 59s 208ms/step - loss: 2.0284 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 58s 206ms/step - loss: 2.0299 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 57s 201ms/step - loss: 2.0305 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 55s 195ms/step - loss: 2.0312 - sparse_categorical_accuracy: 0.52 ━━━━━━━━━━━━━━━━━━━━ 53s 189ms/step - loss: 2.0319 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 51s 184ms/step - loss: 2.0318 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 52s 186ms/step - loss: 2.0320 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 51s 183ms/step - loss: 2.0321 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 49s 179ms/step - loss: 2.0320 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - loss: 2.0321 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - loss: 2.0323 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 48s 175ms/step - loss: 2.0325 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 47s 172ms/step - loss: 2.0328 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 46s 170ms/step - loss: 2.0326 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 45s 168ms/step - loss: 2.0325 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 45s 168ms/step - loss: 2.0323 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 45s 167ms/step - loss: 2.0323 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 44s 165ms/step - loss: 2.0323 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 43s 164ms/step - loss: 2.0323 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 43s 162ms/step - loss: 2.0326 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - loss: 2.0328 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 43s 162ms/step - loss: 2.0331 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - loss: 2.0332 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 42s 159ms/step - loss: 2.0333 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 42s 160ms/step - loss: 2.0334 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 41s 159ms/step - loss: 2.0333 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - loss: 2.0332 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 41s 159ms/step - loss: 2.0332 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 40s 158ms/step - loss: 2.0332 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 40s 156ms/step - loss: 2.0333 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 40s 157ms/step - loss: 2.0334 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 40s 156ms/step - loss: 2.0335 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - loss: 2.0337 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - loss: 2.0337 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - loss: 2.0337 - sparse_categorical_accuracy: 0.51 ━━━━━━━━━━━━━━━━━━━━ 38s 155ms/step - loss: 2.0337 - sparse_ ...
# Epoch 12/200
# ...
# Epoch 23/200
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 1:44 353ms/step - loss: 1.9180 - sparse_categorical_accuracy: 0.218 ━━━━━━━━━━━━━━━━━━━━ 1:28 301ms/step - loss: 1.9205 - sparse_categorical_accuracy: 0.238 ━━━━━━━━━━━━━━━━━━━━ 1:17 266ms/step - loss: 1.9196 - sparse_categorical_accuracy: 0.242 ━━━━━━━━━━━━━━━━━━━━ 1:07 231ms/step - loss: 1.9171 - sparse_categorical_accuracy: 0.244 ━━━━━━━━━━━━━━━━━━━━ 1:06 229ms/step - loss: 1.9102 - sparse_categorical_accuracy: 0.247 ━━━━━━━━━━━━━━━━━━━━ 1:02 217ms/step - loss: 1.9045 - sparse_categorical_accuracy: 0.251 ━━━━━━━━━━━━━━━━━━━━ 58s 204ms/step - loss: 1.9011 - sparse_categorical_accuracy: 0.253 ━━━━━━━━━━━━━━━━━━━━ 58s 203ms/step - loss: 1.8980 - sparse_categorical_accuracy: 0.25 ━━━━━━━━━━━━━━━━━━━━ 59s 207ms/step - loss: 1.8962 - sparse_categorical_accuracy: 0.25 ━━━━━━━━━━━━━━━━━━━━ 58s 206ms/step - loss: 1.8933 - sparse_categorical_accuracy: 0.25 ━━━━━━━━━━━━━━━━━━━━ 56s 199ms/step - loss: 1.8904 - sparse_categorical_accuracy: 0.26 ━━━━━━━━━━━━━━━━━━━━ 56s 199ms/step - loss: 1.8873 - sparse_categorical_accuracy: 0.26 ━━━━━━━━━━━━━━━━━━━━ 54s 192ms/step - loss: 1.8848 - sparse_categorical_accuracy: 0.26 ━━━━━━━━━━━━━━━━━━━━ 52s 186ms/step - loss: 1.8823 - sparse_categorical_accuracy: 0.26 ━━━━━━━━━━━━━━━━━━━━ 50s 180ms/step - loss: 1.8798 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - loss: 1.8778 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 47s 171ms/step - loss: 1.8764 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 47s 171ms/step - loss: 1.8747 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 46s 168ms/step - loss: 1.8731 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 45s 165ms/step - loss: 1.8712 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 44s 163ms/step - loss: 1.8697 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 44s 164ms/step - loss: 1.8681 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - loss: 1.8667 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 43s 159ms/step - loss: 1.8652 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 42s 157ms/step - loss: 1.8639 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 42s 158ms/step - loss: 1.8627 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 42s 156ms/step - loss: 1.8616 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - loss: 1.8606 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 1.8596 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - loss: 1.8589 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 1.8584 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - loss: 1.8578 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 40s 152ms/step - loss: 1.8573 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 39s 152ms/step - loss: 1.8567 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 39s 151ms/step - loss: 1.8563 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 39s 151ms/step - loss: 1.8558 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - loss: 1.8554 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8550 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - loss: 1.8546 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - loss: 1.8542 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8538 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - loss: 1.8534 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8530 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8525 - sparse_categorical_accuracy: 0.30 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - loss: 1.8521 - sparse_categorical_accuracy: 0.30 ━━━━━━━━━━━━━━━━━━━━ 37s 151ms/step - loss: 1.8517 - sparse_cate ...
# Epoch 24/200
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 41s 142ms/step - loss: 1.7675 - sparse_categorical_accuracy: 0.25 ━━━━━━━━━━━━━━━━━━━━ 47s 162ms/step - loss: 1.7825 - sparse_categorical_accuracy: 0.25 ━━━━━━━━━━━━━━━━━━━━ 40s 137ms/step - loss: 1.7829 - sparse_categorical_accuracy: 0.25 ━━━━━━━━━━━━━━━━━━━━ 49s 168ms/step - loss: 1.7845 - sparse_categorical_accuracy: 0.26 ━━━━━━━━━━━━━━━━━━━━ 1:03 219ms/step - loss: 1.7855 - sparse_categorical_accuracy: 0.264 ━━━━━━━━━━━━━━━━━━━━ 1:04 222ms/step - loss: 1.7861 - sparse_categorical_accuracy: 0.266 ━━━━━━━━━━━━━━━━━━━━ 1:02 216ms/step - loss: 1.7870 - sparse_categorical_accuracy: 0.268 ━━━━━━━━━━━━━━━━━━━━ 1:02 216ms/step - loss: 1.7912 - sparse_categorical_accuracy: 0.268 ━━━━━━━━━━━━━━━━━━━━ 59s 206ms/step - loss: 1.7948 - sparse_categorical_accuracy: 0.270 ━━━━━━━━━━━━━━━━━━━━ 58s 204ms/step - loss: 1.7966 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 56s 198ms/step - loss: 1.7976 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 56s 198ms/step - loss: 1.7980 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 55s 195ms/step - loss: 1.7983 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 55s 198ms/step - loss: 1.7987 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 53s 192ms/step - loss: 1.7995 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 54s 194ms/step - loss: 1.8004 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 53s 191ms/step - loss: 1.8015 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 53s 193ms/step - loss: 1.8022 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 52s 188ms/step - loss: 1.8029 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 50s 184ms/step - loss: 1.8037 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 49s 180ms/step - loss: 1.8044 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 48s 176ms/step - loss: 1.8050 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 47s 173ms/step - loss: 1.8054 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 47s 173ms/step - loss: 1.8058 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 46s 170ms/step - loss: 1.8064 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 45s 168ms/step - loss: 1.8069 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 44s 165ms/step - loss: 1.8074 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 43s 163ms/step - loss: 1.8077 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - loss: 1.8081 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 43s 163ms/step - loss: 1.8084 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - loss: 1.8086 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 42s 159ms/step - loss: 1.8087 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - loss: 1.8088 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 40s 156ms/step - loss: 1.8089 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 40s 155ms/step - loss: 1.8090 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 40s 155ms/step - loss: 1.8091 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 39s 153ms/step - loss: 1.8093 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 39s 152ms/step - loss: 1.8094 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8097 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - loss: 1.8098 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8100 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 38s 151ms/step - loss: 1.8101 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - loss: 1.8102 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - loss: 1.8103 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - loss: 1.8104 - sparse_categorical_accuracy: 0.29 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - loss: 1.8105 - sparse_categori ...
# WARNING:dvclive:Error in save_dvc_exp: output '../data/evaluate/pitcher_data.pickle' does not exist
# Most common pitch rate for Nola, Aaron: 0.31185423841795357
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - loss: 2.1320 - sparse_categorical_accuracy: 0.312 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 2.0872 - sparse_categorical_accuracy: 0.304 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 2.0621 - sparse_categorical_accuracy: 0.30 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 2.0572 - sparse_categorical_accuracy: 0.30 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 2.0636 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - loss: 2.0649 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step - loss: 2.0652 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step - loss: 2.0663 - sparse_categorical_accuracy: 0.2764 ━━━━━━━━━━━━━━━━━━━━ 11s 96ms/step - loss: 2.0649 - sparse_categorical_accuracy: 0.277 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - loss: 2.0648 - sparse_categorical_accuracy: 0.277 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - loss: 2.0639 - sparse_categorical_accuracy: 0.277 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - loss: 2.0647 - sparse_categorical_accuracy: 0.276 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - loss: 2.0665 - sparse_categorical_accuracy: 0.276 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - loss: 2.0682 - sparse_categorical_accuracy: 0.274 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - loss: 2.0688 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 2.0695 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - loss: 2.0697 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - loss: 2.0696 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - loss: 2.0690 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - loss: 2.0686 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - loss: 2.0682 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - loss: 2.0682 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 2.0684 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 2.0684 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 2.0685 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 2.0684 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 2.0680 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 2.0678 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 2.0686 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.0694 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 2.0712 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 2.0733 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2.0753 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2.0773 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 2.0784 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2.0811 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 2.0840 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 2.0867 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 2.0889 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 2.0911 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 2.0932 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 2.0952 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 2.0970 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 2.0988 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 2.1005 - sparse_categorical_accuracy: 0.28 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 2.1023 - sparse_categorical_accuracy: 0.27 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 2.1039 - sparse_categ ...
# 2025-01-01 02:12:23,171 - choo choo - INFO - Test Loss: 2.1318, Test Accuracy: 0.29
# 2025-01-01 02:12:23,171 - choo choo - INFO - Test Loss: 2.1318, Test Accuracy: 0.29
# 2025-01-01 02:12:23,171 - choo choo - INFO -  Accuracy Gained over guessing most common pitch for Nola, Aaron: -2.04%
# 2025-01-01 02:12:23,171 - choo choo - INFO -  Accuracy Gained over guessing most common pitch for Nola, Aaron: -2.04%
# 2025-01-01 02:12:23,172 - choo choo - INFO - Average Test Accuracy: 40.47%
# 2025-01-01 02:12:23,172 - choo choo - INFO - Average Test Accuracy: 40.47%
# 2025-01-01 02:12:23,173 - choo choo - INFO - Average Performance Gained over guessing most common pitch: -0.48%
# 2025-01-01 02:12:23,173 - choo choo - INFO - Average Performance Gained over guessing most common pitch: -0.48%
# 2025-01-01 02:12:23,179 - choo choo - INFO - 5 of 5, 100.00% done!
# 2025-01-01 02:12:23,179 - choo choo - INFO - 5 of 5, 100.00% done!
# 2025-01-01 02:12:23,181 - choo choo - INFO - Training took 22100.58839917183 seconds
# 2025-01-01 02:12:23,181 - choo choo - INFO - Training took 22100.58839917183 seconds
